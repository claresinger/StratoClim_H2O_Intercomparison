# %%
from importlib import reload
from read_idl import idlToPandas

# %%
dat = idlToPandas('./Data/20210224dat-5s.sav')
dat0 = dat

# %%
## Table 2 and 3
import tables
reload(tables)
from tables import *
table2(dat)
table3(dat)
# Out:
# 2
# 1.59 / 2.98 / 2.32 & 0.00 / 0.00 / - & 1.59 / 2.98 / 2.32
# 3
# 1.07 / 2.23 / 0.00 & 0.08 / 0.08 / - & 0.99 / 2.15 / 0.00
# 4
# 1.77 / 2.90 / 0.86 & 0.71 / 0.73 / - & 1.07 / 2.17 / 0.86
# 6
# 2.52 / 2.48 / 0.45 & 1.62 / 1.61 / - & 0.89 / 0.87 / 0.45
# 7
# 1.22 / 1.23 / 0.28 & 0.83 / 0.79 / - & 0.39 / 0.44 / 0.28
# 8
# 1.72 / 2.13 / 0.11 & 1.35 / 1.35 / - & 0.37 / 0.78 / 0.11
# 51
# 4.43 / 8.11 / 3.18 & 0.79 / 0.81 / - & 3.65 / 7.30 / 3.18
# 52
# 5.46 / 5.84 / 0.84 & 3.81 / 3.75 / - & 1.65 / 2.09 / 0.84
# 0
# 9.89 / 13.95 / 4.01 & 4.60 / 4.56 / - & 5.29 / 9.39 / 4.01
# 1
# -2.3 (4.4) & -- & -10.1 (4.3) & 11.5 (5.9) & 6.0 (4.3) & 10.8 (4.0) & -4.4 (5.6) & 9.6 (5.8) & -1.5 (8.0) &
# 2
# 4.4 (4.9) & -- & -6.4 (4.0) & 8.2 (4.3) & 8.4 (10.2) & 3.5 (2.9) & -0.8 (7.0) & 8.2 (6.9) &
# /Users/claresinger/Research/StratoClim_H2O_Intercomparison/tables.py:157: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# ...

# %%
## Fig 1
import fig1_overview
reload(fig1_overview)
from fig1_overview import *
map_alt_h2o(dat)
# Out:
# (126,)

# %%
## Fig 2
import fig2_cloud_mask
reload(fig2_cloud_mask)
from fig2_cloud_mask import *
cloud_mask(dat)

# %%
## Fig 3
import fig3_scatter_h2o
reload(fig3_scatter_h2o)
from fig3_scatter_h2o import *
h2o_pt_by_pt_whist6(dat)
# Out:
# a
# 100 0 r2= 0.9933000072009919
# mean bias =  -1.3059128522872925 %
# std bias =  8.039379119873047 %
#
# a
# 10 0 r2= 0.9295888372520545
# mean bias =  -1.4721014499664307 %
# std bias =  8.034934043884277 %
# 78.0 < 10% diff
# 99.0 < 20% diff
#
# b
# 100 1 r2= 0.98749602273192
# mean bias =  -1.4329293966293335 %
# std bias =  6.2304582595825195 %
#
# mean bias (all sky) =  -0.6157707571983337 %
# std bias (all sky) =  7.001147270202637 %
# b
# 10 1 r2= 0.927918906169753
# mean bias =  -1.4189949035644531 %
# std bias =  5.875345230102539 %
# 92.0 < 10% diff
# 100.0 < 20% diff
#
# mean bias (all sky) =  -0.42406028509140015 %
# std bias (all sky) =  6.811517715454102 %
# c
# 100 2 r2= 0.9936203040256393
# mean bias =  0.27770712971687317 %
# std bias =  7.659101963043213 %
#
# c
# 10 2 r2= 0.9296024310572593
# mean bias =  0.7357591986656189 %
# std bias =  7.600751876831055 %
# 87.0 < 10% diff
# 98.0 < 20% diff

# %%
## Fig 4
import fig4_diff_hist
reload(fig4_diff_hist)
from fig4_diff_hist import *
dry_errors_2rows(dat)
# Out:
# 8117 5579
# 0.23884956538677216 0.40462642908096313
# 0 3564
# nan 0.3742870092391968
# 3403 4569
# 0.2583875060081482 0.2929270565509796
# 1612 3140
# 0.3035804033279419 0.21906478703022003
# 983 1386
# 0.22280842065811157 0.43724921345710754
# 401 1165
# 0.17155370116233826 0.19850359857082367
# /Users/claresinger/opt/anaconda3/envs/basemap/lib/python3.7/site-packages/numpy/lib/histograms.py:906: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /Users/claresinger/opt/anaconda3/envs/basemap/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/claresinger/opt/anaconda3/envs/basemap/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)

# %%
## Fig 5
import fig5_diff_profiles
reload(fig5_diff_profiles)
from fig5_diff_profiles import *
h2o_diff_profs_clr_cloud(dat)

# %%
## Fig 6
import fig6_f2f7
reload(fig6_f2f7)
from fig6_f2f7 import *
h2o_f2_f7(dat)

# %%
## Fig 7
import fig7_rhi_freq
reload(fig7_rhi_freq)
from fig7_rhi_freq import *
rhi_temp_freq(dat)
# Out:
# ChiWIS
# 5.5938888888888885 5.353611111111111  hrs (clear, cloudy)
# clear  ChiWIS mean =  0.78775996 median =  0.78378314
# cloudy  ChiWIS mean =  1.0745037 median =  1.0714747
# FLASH
# 9.747222222222222 5.163611111111111  hrs (clear, cloudy)
# clear  FLASH mean =  0.5103336 median =  0.53719664
# cloudy  FLASH mean =  1.0671357 median =  1.065446
# FISH
# 4.132777777777778  hrs (clear)
# clear  FISH mean =  0.52212375 median =  0.5405656

# %%
## Fig 8
import fig8_scatter_rhi
reload(fig8_scatter_rhi)
from fig8_scatter_rhi import *
rhi_pt_by_pt_whist6(dat)
# Out:
# 0 r2= 0.9776964506504261
# mean bias =  -1.3054587841033936 %
# std bias =  8.02466869354248 %
#
# 1 r2= 0.9579328689773855
# mean bias =  -1.4329286813735962 %
# std bias =  6.2304582595825195 %
#
# 2 r2= 0.8874395608746456
# mean bias =  0.2777075171470642 %
# std bias =  7.659102439880371 %

# %%
## Fig 9
import fig9_mean_profiles
reload(fig9_mean_profiles)
from fig9_mean_profiles import *
mean_profile_compare(dat)
# Out:
# PT compared:  [383. 390. 397. 404. 411. 418. 425. 432. 439. 446. 453. 460. 467. 474.
#  481. 488. 495.]
# v5 diff in warm/wet:  -14.71933264301431
# v5 diff in cold/dry:  -14.162814244567437
#
# % bias from MLS v5
# PT compared:  [374. 378. 382. 386. 390. 394. 398. 402. 406.]
# chiwis warm/wet: -19.5 \pm 7.1
# flash warm/wet: -22.2 \pm 5.9
# chiwis cold/dry: -11.5 \pm 11.3
# flash cold/dry: -10.6 \pm 11.5
# balloon cold/dry: -4.9 \pm 13.5
#
# % bias from MLS v4
# PT compared:  [374. 378. 382. 386. 390. 394. 398. 402. 406.]
# chiwis warm/wet: -7.2 \pm 9.4
# flash warm/wet: -10.3 \pm 7.8
# chiwis cold/dry: 0.1 \pm 10.7
# flash cold/dry: 1.1 \pm 10.8
# balloon cold/dry: 7.6 \pm 13.1

# %%
## Supp Fig 1
import figS1_h2o_timeseries
reload(figS1_h2o_timeseries)
from figS1_h2o_timeseries import *
h2o_timeseries_all(dat)

# %%
## Supp Fig 2
import figS2_h2o_profiles
reload(figS2_h2o_profiles)
from figS2_h2o_profiles import *
h2o_profiles_all(dat)

# %%
## Supp Fig 3
import figS3_rhi_timeseries
reload(figS3_rhi_timeseries)
from figS3_rhi_timeseries import *
rhi_timeseries_all(dat)

# %%
## Supp Fig 4
import figS4_rhi_profiles
reload(figS4_rhi_profiles)
from figS4_rhi_profiles import *
rhi_profiles_all(dat)

# %%
## Supp Fig 5
import figS5_precision
reload(figS5_precision)
from figS5_precision import *
precision_f4(dat)

# %%
## Supp Fig 6
import figS6_cloud_lag
reload(figS6_cloud_lag)
from figS6_cloud_lag import *
frac_error_pdfs(dat)
# Out:
# /Users/claresinger/Research/StratoClim_H2O_Intercomparison/figS6_cloud_lag.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dati['CLOUDY'] = np.maximum(dati['CLOUDY'], dati.shift(periods=lag, fill_value=0.0)['CLOUDY'])
# /Users/claresinger/Research/StratoClim_H2O_Intercomparison/figS6_cloud_lag.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dati['CLOUDY'] = np.maximum(dati['CLOUDY'], dati.shift(periods=lag, fill_value=0.0)['CLOUDY'])
# ...

# %%
## Supp Fig 7
import figS7_scatter_h2o_oor
reload(figS7_scatter_h2o_oor)
from figS7_scatter_h2o_oor import *
h2o_pt_by_pt_whist_oor(dat)
# Out:
# a
# 100 0 r2= 0.98749602273192
# mean bias =  -1.4329293966293335 %
# std bias =  6.2304582595825195 %
# a
# 10 0 r2= 0.927918906169753
# mean bias =  -1.4189949035644531 %
# std bias =  5.875345230102539 %
# b
# 100 1 r2= 0.36711435333237996
# mean bias =  8.43593978881836 %
# std bias =  8.003376007080078 %
# b
# 10 1 r2= 0.36711435333237996
# mean bias =  8.43593978881836 %
# std bias =  8.003376007080078 %

# %%
## Supp Fig 8
import figS8_rhi_freq_oor
reload(figS8_rhi_freq_oor)
from figS8_rhi_freq_oor import *
rhi_temp_freq_oor(dat)
# Out:
# ChiWIS 0.78775996 0.78378314
# ChiWIS 0.50732195 0.5559628

# %%
## Supp Fig 9
import figS9_scatter_rhi_oor
reload(figS9_scatter_rhi_oor)
from figS9_scatter_rhi_oor import *
rhi_pt_by_pt_whist_oor(dat)
# Out:
# a
# 0 r2= 0.9579328689773855
# mean bias =  -1.4329286813735962 %
# std bias =  6.2304582595825195 %
#
# b
# 1 r2= 0.9817577196985917
# mean bias =  8.43593978881836 %
# std bias =  8.003376007080078 %
