# %%
from importlib import reload
from read_idl import idlToPandas
import numpy as np
import matplotlib.pyplot as plt

# %%
dat = idlToPandas('./Data/20210224dat-5s.sav')
dat0 = dat

# %%
## Fig 1
import fig1_overview
reload(fig1_overview)
from fig1_overview import *
map_alt_h2o(dat)
# Out:
# (118,)

# %%
## Fig 2
import fig2_scatter_h2o
reload(fig2_scatter_h2o)
from fig2_scatter_h2o import *
h2o_pt_by_pt_whist6(dat)
# Out:
# a
# 100 0 r2= 0.9933000072009919
# mean bias =  -1.305918 %
#
# a
# 10 0 r2= 0.9295888372520545
# mean bias =  -1.4721065 %
# 78.0 < 10% diff
# 99.0 < 20% diff
#
# b
# 100 1 r2= 0.98749602273192
# mean bias =  -1.4329295 %
#
# b
# 10 1 r2= 0.927918906169753
# mean bias =  -1.4189986 %
# 92.0 < 10% diff
# 100.0 < 20% diff
#
# c
# 100 2 r2= 0.9936203040256393
# mean bias =  0.2777074 %
#
# c
# 10 2 r2= 0.9296024310572593
# mean bias =  0.73575836 %
# 87.0 < 10% diff
# 98.0 < 20% diff

# %%
## Fig 3
import fig3_diff_hist
reload(fig3_diff_hist)
from fig3_diff_hist import *
dry_errors_2rows(dat)
# Out:
# 8117 5579
# 0.2388496 0.40462634
# 0 3564
# nan 0.374287
# 3403 4569
# 0.25838712 0.292927
# 1612 3140
# 0.30358043 0.2190647
# 983 1386
# 0.2228084 0.43724927
# 401 1165
# 0.17155372 0.1985036

# %%
## Fig 4
import fig4_diff_profiles
reload(fig4_diff_profiles)
from fig4_diff_profiles import *
h2o_diff_profs_clr_cloud(dat)

# %%
## Fig 5
import fig5_f2f7
reload(fig5_f2f7)
from fig5_f2f7 import *
h2o_f2_f7(dat)

# %%
## Fig 6
import fig6_rhi_freq
reload(fig6_rhi_freq)
from fig6_rhi_freq import *
rhi_temp_freq(dat)
# Out:
# ChiWIS
# 5.5938888888888885 5.353611111111111
# ChiWIS 0.78776 0.78378314
# ChiWIS 1.0745038 1.0714747
# FLASH
# 11.297222222222222 6.501666666666667
# FLASH 0.5158043 0.5478981
# FLASH 1.0485779 1.042856
# FISH
# 4.1497222222222225
# FISH 0.52339387 0.54407144

# %%
## Fig 7
import fig7_scatter_rhi
reload(fig7_scatter_rhi)
from fig7_scatter_rhi import *
rhi_pt_by_pt_whist6(dat)
# Out:
# 0 r2= 0.9776964506504261
# mean bias =  -1.3054643757641315 %
# 1 r2= 0.9579328689773855
# mean bias =  -1.4329293742775917 %
# 2 r2= 0.8874395608746456
# mean bias =  0.2777073998004198 %
# 3 r2= 0.9776964506504261
# mean bias =  -1.3054643757641315 %
# 4 r2= 0.9579328689773855
# mean bias =  -1.4329293742775917 %
# 5 r2= 0.8874395608746456
# mean bias =  0.2777073998004198 %

# %%
## Fig 8
import fig8_mean_profiles
reload(fig8_mean_profiles)
from fig8_mean_profiles import *
mean_profile_compare(dat)
# Out:
# % bias from MLS
# [383. 390. 397. 404. 411. 418. 425. 432. 439.]
# chiwis  4.454392747425611
# flash  3.77900605646126
# chiwis  -4.5658885096254185
# flash  -3.301755098557022
# balloon  -1.9978175984528823

# %%
## Supp Fig 1
import figS1_h2o_timeseries
reload(figS1_h2o_timeseries)
from figS1_h2o_timeseries import *
h2o_timeseries_all(dat)

# %%
## Supp Fig 2
import figS2_h2o_profiles
reload(figS2_h2o_profiles)
from figS2_h2o_profiles import *
h2o_profiles_all(dat)

# %%
## Supp Fig 3
import figS7_rhi_timeseries
reload(figS7_rhi_timeseries)
from figS7_rhi_timeseries import *
rhi_timeseries_all(dat)

# %%
## Supp Fig 4
import figS8_rhi_profiles
reload(figS8_rhi_profiles)
from figS8_rhi_profiles import *
rhi_profiles_all(dat)

# %%
## Supp Fig 5
import figSx_precision
reload(figSx_precision)
from figSx_precision import *
precision_f4(dat)

# %%
## Supp Fig 6
import figS3_cloud_mask
reload(figS3_cloud_mask)
from figS3_cloud_mask import *
cloud_mask(dat)

# %%
## Supp Fig 7
import figS4_cloud_lag
reload(figS4_cloud_lag)
from figS4_cloud_lag import *
frac_error_pdfs(dat)

# %%
## Supp Fig 8
import fig2_scatter_h2o
reload(fig2_scatter_h2o)
from fig2_scatter_h2o import *
h2o_pt_by_pt_whist_oor(dat)
# Out:
# a
# 100 0 r2= 0.98749602273192
# mean bias =  -1.4329293742775917 %
# a
# 10 0 r2= 0.927918906169753
# mean bias =  -1.4189988374710083 %
# b
# 100 1 r2= 0.36711435333237996
# mean bias =  8.435944467782974 %
# b
# 10 1 r2= 0.36711435333237996
# mean bias =  8.435944467782974 %

# %%
## Supp Fig 9
import fig6_rhi_freq
reload(fig6_rhi_freq)
from fig6_rhi_freq import *
rhi_temp_freq_oor(dat)
# Out:
# ChiWIS 0.78775996 0.78378314
# ChiWIS 0.507322 0.5559628

# %%
## Supp Fig 10
import fig7_scatter_rhi
reload(fig7_scatter_rhi)
from fig7_scatter_rhi import *
rhi_pt_by_pt_whist_oor(dat)
# Out:
# a
# 0 r2= 0.9579328689773855
# mean bias =  -1.4329293742775917 %
# b
# 1 r2= 0.9817577196985917
# mean bias =  8.435944467782974 %
